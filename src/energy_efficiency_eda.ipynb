# %% [markdown]
# **Title: Exploratory data analysis of the Energy Efficiency data set**

# %% [markdown]
# **Summary of the data set**
#
# The data set used in this exploratory data analysis is retrieved from "http://archive.ics.uci.edu/ml/datasets/Energy+efficiency#". It was contributed by Angeliki Xifara (angxifara '@' gmail.com, Civil/Structural Engineer) and was processed by Athanasios Tsanas (tsanasthanasis '@' gmail.com, Oxford Centre for Industrial and Applied Mathematics, University of Oxford, UK). It contains 768 instances and was donated at 2012-11-30. It has no missing values. It has a total of 10 variables, with 8 of them are attributes(features) and two responses. The authors suggested that the aim of this data set is to use the eight features to predict the two responses. These variables are shown in the table below:

# %% [markdown]
# | Variable name in data set| Description |
# | --- | --- |
# | X1 | Relative Compactness |
# | X2 | Surface Area |
# | X3 | Wall Area |
# | X4 | Roof Area |
# | X5 | Overall Height |
# | X6 | Orientation |
# | X7 | Glazing Area |
# | X8 | Glazing Area Distribution |
# | y1 | Heating Load |
# | y2 | Cooling Load |

# %% [markdown]
# **Partition the data set into training and test sub-data sets**
#
# The whole data set were divided into train and test sets, with 70% train data and 30% test data.

# %% [markdown]
# | Number of cases| Sub data set |
# | --- | --- |
# | 537 | Train set |
# | 231 | Test set |

# %% [markdown]
# **Exploratory data analysis with the train set**
#
# The exploratory data analysis were conducted through the following steps:
# 1.load in the necessary packages and split the data into train and test sets, NaN were dropped;
# 2.do EDA on the train set. First to check the data types and see if there are missing values; we found out that there is no missing value. Then we proceed to see the data distribution through bar plots, value_counts, correlations. Through the EDA, we could identify that all the variables are numeric type, but Roof Area', 'Surface Area', 'Wall Area', 'Overall Height', 'Orientation', 'Glazing Area', and 'Glazing Area Distribution' are actually categorical.
# 3.From the above analysis, we may proceed to do a supervised machine learning model with data preprocessed by Standard Scaling and One Hot Encode on the numeric features with Heating Load and Cooling Load as the targets.

# %%
# load the packages
import pandas as pd
import numpy as np
import altair as alt
from sklearn.model_selection import train_test_split

# %%
# read in data set
# rename the attributes
# source:http://archive.ics.uci.edu/ml/datasets/Energy+efficiency#
energy_data = pd.read_csv('C:/Users/yaouh/energy_efficiency_analysis/data/ENB2012data.csv').dropna()
energy_data = energy_data.rename(columns = {'X1':'Relative Compactness',
                                            'X2':'Surface Area',
                                            'X3':'Wall Area',
                                            'X4':'Roof Area',
                                            'X5':'Overall Height',
                                            'X6':'Orientation',
                                            'X7':'Glazing Area',
                                            'X8':'Glazing Area Distribution',
                                            'Y1':'Heating Load',
                                            'Y2':'Cooling Load'})
train_df, test_df = train_test_split(energy_data, test_size = 0.3, random_state = 4)

# %%
# check the data types and see if there are missing values
train_df.info()
train_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 262 to 122
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative Compactness       537 non-null    float64
#  1   Surface Area               537 non-null    float64
#  2   Wall Area                  537 non-null    float64
#  3   Roof Area                  537 non-null    float64
#  4   Overall Height             537 non-null    float64
#  5   Orientation                537 non-null    float64
#  6   Glazing Area               537 non-null    float64
#  7   Glazing Area Distribution  537 non-null    float64
#  8   Heating Load               537 non-null    float64
#  9   Cooling Load               537 non-null    float64
# dtypes: float64(10)
# memory usage: 46.1 KB
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 262                  0.76         661.5      416.5     122.50             7.0
# 619                  0.64         784.0      343.0     220.50             3.5
# 275                  0.69         735.0      294.0     220.50             3.5
# 338                  0.98         514.5      294.0     110.25             7.0
# 177                  0.69         735.0      294.0     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 262          4.0          0.10                        5.0         32.46
# 619          5.0          0.40                        2.0         19.12
# 275          5.0          0.10                        5.0         11.16
# 338          4.0          0.25                        2.0         28.18
# 177          3.0          0.10                        3.0         11.16
#
#      Cooling Load
# 262         33.64
# 619         21.93
# 275         14.39
# 338         30.18
# 177         14.27

# %%
train_df.describe(include="number")
# Out:
#        Relative Compactness  Surface Area   Wall Area   Roof Area  \
# count            537.000000    537.000000  537.000000  537.000000
# mean               0.765866    670.533520  319.001862  175.765829
# std                0.107296     89.237801   42.682258   45.300412
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.660000    588.000000  294.000000  122.500000
# 50%                0.760000    661.500000  318.500000  147.000000
# 75%                0.860000    759.500000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall Height  Orientation  Glazing Area  Glazing Area Distribution  \
# count      537.000000   537.000000    537.000000                 537.000000
# mean         5.279330     3.521415      0.233892                   2.828678
# std          1.751386     1.114695      0.132873                   1.575369
# min          3.500000     2.000000      0.000000                   0.000000
# 25%          3.500000     3.000000      0.100000                   2.000000
# 50%          7.000000     4.000000      0.250000                   3.000000
# 75%          7.000000     5.000000      0.400000                   4.000000
# max          7.000000     5.000000      0.400000                   5.000000
#
#        Heating Load  Cooling Load
# count    537.000000    537.000000
# mean      22.421750     24.709423
# std       10.128379      9.599911
# min        6.010000     10.900000
# 25%       13.000000     15.730000
# 50%       19.200000     22.720000
# 75%       31.530000     33.040000
# max       43.100000     48.030000

# %%
train_df['Relative Compactness'].value_counts()
# Out:
# 0.90    49
# 0.79    48
# 0.98    47
# 0.62    47
# 0.69    46
# 0.82    46
# 0.66    45
# 0.64    43
# 0.76    42
# 0.74    42
# 0.86    41
# 0.71    41
# Name: Relative Compactness, dtype: int64

# %%
train_df['Surface Area'].value_counts()
# Out:
# 563.5    49
# 637.0    48
# 514.5    47
# 808.5    47
# 735.0    46
# 612.5    46
# 759.5    45
# 784.0    43
# 661.5    42
# 686.0    42
# 588.0    41
# 710.5    41
# Name: Surface Area, dtype: int64

# %%
train_df['Roof Area'].value_counts()
# Out:
# 220.50    264
# 147.00    135
# 122.50     91
# 110.25     47
# Name: Roof Area, dtype: int64

# %%
train_df['Overall Height'].value_counts()
# Out:
# 7.0    273
# 3.5    264
# Name: Overall Height, dtype: int64

# %%
train_df['Orientation'].value_counts()
# Out:
# 5.0    137
# 3.0    136
# 4.0    135
# 2.0    129
# Name: Orientation, dtype: int64

# %%
train_df['Glazing Area'].value_counts()
# Out:
# 0.25    176
# 0.40    164
# 0.10    160
# 0.00     37
# Name: Glazing Area, dtype: int64

# %%
train_df['Glazing Area Distribution'].value_counts()
# Out:
# 5.0    105
# 4.0    104
# 2.0    101
# 1.0     97
# 3.0     93
# 0.0     37
# Name: Glazing Area Distribution, dtype: int64

# %%
# check the distribution of all variables
column_list = train_df.columns.tolist()

distri_chart = alt.Chart(train_df, 
                         title = 'Bar chart of variable distribution'
                        ).mark_bar(opacity = 0.5).encode(
    alt.X (alt.repeat(),
           type = 'quantitative',
          bin = alt.Bin(maxbins = 45)),
    alt.Y('count()', stack = None),
    tooltip = 'count()'
).properties(width = 150,
            height = 150).repeat(
repeat = column_list,
columns = 2)

distri_chart
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# **As shown above, although all variables are numeric type, from the results of the bar charts and the value_counts of each variable, 'Roof Area', 'Surface Area', 'Wall Area', 'Overall Height', 'Orientation', 'Glazing Area', and 'Glazing Area Distribution' are actually categorical.**

# %%
# correlation matrix
energy_data.corr('spearman').style.background_gradient()
# Out:
# <style type="text/css">
# #T_2a9ec_row0_col0, #T_2a9ec_row1_col1, #T_2a9ec_row2_col2, #T_2a9ec_row3_col3, #T_2a9ec_row4_col4, #T_2a9ec_row5_col5, #T_2a9ec_row6_col6, #T_2a9ec_row7_col7, #T_2a9ec_row8_col8, #T_2a9ec_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2a9ec_row0_col1, #T_2a9ec_row0_col2, #T_2a9ec_row0_col6, #T_2a9ec_row0_col7, #T_2a9ec_row1_col0, #T_2a9ec_row1_col6, #T_2a9ec_row1_col7, #T_2a9ec_row2_col6, #T_2a9ec_row2_col7, #T_2a9ec_row3_col4, #T_2a9ec_row3_col6, #T_2a9ec_row3_col7, #T_2a9ec_row3_col8, #T_2a9ec_row3_col9, #T_2a9ec_row4_col3, #T_2a9ec_row4_col6, #T_2a9ec_row4_col7, #T_2a9ec_row5_col6, #T_2a9ec_row5_col7, #T_2a9ec_row8_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2a9ec_row0_col3, #T_2a9ec_row1_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_2a9ec_row0_col4, #T_2a9ec_row1_col3, #T_2a9ec_row9_col4 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_2a9ec_row0_col5, #T_2a9ec_row1_col5, #T_2a9ec_row2_col5, #T_2a9ec_row3_col5, #T_2a9ec_row4_col5, #T_2a9ec_row6_col5, #T_2a9ec_row7_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2a9ec_row0_col8 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_2a9ec_row0_col9 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_2a9ec_row1_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_2a9ec_row1_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_2a9ec_row1_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2a9ec_row2_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_2a9ec_row2_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_2a9ec_row2_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_2a9ec_row2_col4 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_2a9ec_row2_col8 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_2a9ec_row2_col9 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_2a9ec_row3_col0, #T_2a9ec_row4_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_2a9ec_row3_col1, #T_2a9ec_row4_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_2a9ec_row3_col2, #T_2a9ec_row9_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_2a9ec_row4_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_2a9ec_row4_col8, #T_2a9ec_row4_col9 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_2a9ec_row5_col0, #T_2a9ec_row5_col1, #T_2a9ec_row6_col0, #T_2a9ec_row6_col1, #T_2a9ec_row7_col0, #T_2a9ec_row7_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_2a9ec_row5_col2, #T_2a9ec_row6_col2, #T_2a9ec_row7_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_2a9ec_row5_col3, #T_2a9ec_row5_col4, #T_2a9ec_row6_col3, #T_2a9ec_row6_col4, #T_2a9ec_row7_col3, #T_2a9ec_row7_col4, #T_2a9ec_row7_col8 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_2a9ec_row5_col8 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_2a9ec_row5_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_2a9ec_row6_col7, #T_2a9ec_row7_col6, #T_2a9ec_row8_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_2a9ec_row6_col8 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_2a9ec_row6_col9 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_2a9ec_row7_col9 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_2a9ec_row8_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_2a9ec_row8_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_2a9ec_row8_col3, #T_2a9ec_row8_col7, #T_2a9ec_row9_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_2a9ec_row8_col4 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_2a9ec_row8_col6 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2a9ec_row8_col9, #T_2a9ec_row9_col8 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_2a9ec_row9_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_2a9ec_row9_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_2a9ec_row9_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_2a9ec_row9_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_2a9ec_row9_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# </style>
# <table id="T_2a9ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a9ec_level0_col0" class="col_heading level0 col0" >Relative Compactness</th>
#       <th id="T_2a9ec_level0_col1" class="col_heading level0 col1" >Surface Area</th>
#       <th id="T_2a9ec_level0_col2" class="col_heading level0 col2" >Wall Area</th>
#       <th id="T_2a9ec_level0_col3" class="col_heading level0 col3" >Roof Area</th>
#       <th id="T_2a9ec_level0_col4" class="col_heading level0 col4" >Overall Height</th>
#       <th id="T_2a9ec_level0_col5" class="col_heading level0 col5" >Orientation</th>
#       <th id="T_2a9ec_level0_col6" class="col_heading level0 col6" >Glazing Area</th>
#       <th id="T_2a9ec_level0_col7" class="col_heading level0 col7" >Glazing Area Distribution</th>
#       <th id="T_2a9ec_level0_col8" class="col_heading level0 col8" >Heating Load</th>
#       <th id="T_2a9ec_level0_col9" class="col_heading level0 col9" >Cooling Load</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a9ec_level0_row0" class="row_heading level0 row0" >Relative Compactness</th>
#       <td id="T_2a9ec_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2a9ec_row0_col1" class="data row0 col1" >-1.000000</td>
#       <td id="T_2a9ec_row0_col2" class="data row0 col2" >-0.255805</td>
#       <td id="T_2a9ec_row0_col3" class="data row0 col3" >-0.870886</td>
#       <td id="T_2a9ec_row0_col4" class="data row0 col4" >0.869048</td>
#       <td id="T_2a9ec_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_2a9ec_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_2a9ec_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_2a9ec_row0_col8" class="data row0 col8" >0.622135</td>
#       <td id="T_2a9ec_row0_col9" class="data row0 col9" >0.651019</td>
#     </tr>
#     <tr>
#       <th id="T_2a9ec_level0_row1" class="row_heading level0 row1" >Surface Area</th>
#       <td id="T_2a9ec_row1_col0" class="data row1 col0" >-1.000000</td>
#       <td id="T_2a9ec_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2a9ec_row1_col2" class="data row1 col2" >0.255805</td>
#       <td id="T_2a9ec_row1_col3" class="data row1 col3" >0.870886</td>
#       <td id="T_2a9ec_row1_col4" class="data row1 col4" >-0.869048</td>
#       <td id="T_2a9ec_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_2a9ec_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_2a9ec_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_2a9ec_row1_col8" class="data row1 col8" >-0.622135</td>
#       <td id="T_2a9ec_row1_col9" class="data row1 col9" >-0.651019</td>
#     </tr>
#     <tr>
#       <th id="T_2a9ec_level0_row2" class="row_heading level0 row2" >Wall Area</th>
#       <td id="T_2a9ec_row2_col0" class="data row2 col0" >-0.255805</td>
#       <td id="T_2a9ec_row2_col1" class="data row2 col1" >0.255805</td>
#       <td id="T_2a9ec_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2a9ec_row2_col3" class="data row2 col3" >-0.193457</td>
#       <td id="T_2a9ec_row2_col4" class="data row2 col4" >0.220763</td>
#       <td id="T_2a9ec_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_2a9ec_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_2a9ec_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_2a9ec_row2_col8" class="data row2 col8" >0.471458</td>
#       <td id="T_2a9ec_row2_col9" class="data row2 col9" >0.415991</td>
#     </tr>
#     <tr>
#       <th id="T_2a9ec_level0_row3" class="row_heading level0 row3" >Roof Area</th>
#       <td id="T_2a9ec_row3_col0" class="data row3 col0" >-0.870886</td>
#       <td id="T_2a9ec_row3_col1" class="data row3 col1" >0.870886</td>
#       <td id="T_2a9ec_row3_col2" class="data row3 col2" >-0.193457</td>
#       <td id="T_2a9ec_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2a9ec_row3_col4" class="data row3 col4" >-0.937043</td>
#       <td id="T_2

# %%
# pairwsie scatter plots

scatters = alt.Chart(train_df,
                    title = 'Pairwise correlations').mark_point(opacity = 0.2,
                                       size = 5).encode(
    alt.X (alt.repeat("row"),
           type = 'quantitative',
           scale = alt.Scale(zero = False)),
    alt.Y(alt.repeat("column"),
          type = 'quantitative',
          scale = alt.Scale(zero = False))
).properties(
    width = 120,
    height = 120
).repeat(
    column = column_list,
    row = column_list
)
# Show the plot
scatters
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# **References**
#
# A. Tsanas, A. Xifara: 'Accurate quantitative estimation of energy performance of residential buildings using statistical machine learning tools', Energy and Buildings, Vol. 49, pp. 560-567, 2012 (the paper can be accessed from [Web Link])
#
# For further details on the data analysis methodology:
# A. Tsanas, 'Accurate telemonitoring of Parkinsonâ€™s disease symptom severity using nonlinear speech signal processing and statistical machine learning', D.Phil. thesis, University of Oxford, 2012 (which can be accessed from [Web Link])
